# %%
#pip install pillow

from PIL import Image

# %%
mac = Image.open('my_computerimg.jpg')

# %%
type(mac)
# Out:
# PIL.PngImagePlugin.PngImageFile

# %%
mac#only in JN
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=220x165 at 0x2A4EC5B15B0>

# %%
mac.size
# Out:
# (220, 165)

# %%
mac.filename
# Out:
# 'my_computerimg.jpg'

# %%
##cropping images

mac.crop((0,0,100,100))
# Out:
# <PIL.Image.Image image mode=RGBA size=100x100 at 0x2A4EF4D61F0>

# %%
#mac.paste
#mac.resize
mac.rotate(90)
# Out:
# <PIL.Image.Image image mode=RGBA size=220x165 at 0x2A4EF4D6EB0>

# %%
#color transparency

#RGBA - red green blue Alpha

#blue.putalpha(0)------transparent 

#255--------blue

#128------light blue

#red.putalpha(128)-----light pink

#pasting one image on top of another 

#blue.paste(im = red,box=(0,0),mask = red)-----purple


#blue.save("imagename.png")

# %% [markdown]
# # Files

# %% [markdown]
# #csv files
#
# PANDAS --works with any tabular data
# --runs visulaizations and analysis
# --

# %%
#openpyxl
#googlesheets python API

import csv

# %%
#open the file
data = open('example.csv',encoding ='utf-8')
#csv.reader
csv_data = csv.reader(data)
#reformat into python object
data_lines = list(csv_data)

# %%
data_lines[0]
# Out:
# ['id', 'firstname', 'lastname', 'gender', 'email']

# %%
len(data_lines)
# Out:
# 2

# %%
for line in data_lines[:5]:
    print(line)
# Out:
# ['id', 'firstname', 'lastname', 'gender', 'email']
# ['1', 'sah', 'ponu', 'F', 'sahponu@gmail.com']

# %%
data_lines[1][3]
# Out:
# 'F'

# %%
fullnames = []

# %%
for line in data_lines[1:]:
    fullnames.append(line[1]+' '+line[2])

# %%
fullnames
# Out:
# ['sah ponu']

# %%
file_output = open('tosave_file.csv',mode = 'w',newline = '')

# %%
csv_writer = csv.writer(file_output,delimiter=',')

# %%
csv_writer.writerow(['a','b','c'])
# Out:
# 7

# %%
file_output.close()

# %% [markdown]
# pdf reader- PyPDF2
#
# pip install PyPDF2

# %%
import PyPDF2

# %%
f = open('example.pdf','rb')#readbinary

# %%
#pdf_reader = PyPDF2.PdfFileReader(f)

#pdf_reader.numPages

#pdf_reader.getPage(0)

#pdf_reader.extractText()

# %%
f.close()

# %%
pdf_writer = PyPDF2.PdfFileWriter()

# %%
#pdf_writer.addPage()

# %% [markdown]
# Emails with Python
#
# smptplib(Simple MAil Transfer Protocol)

# %%
import smtplib

# %%
smtp_obj = smtplib.SMTP('smtp.gmail.com',587)

# %%
smtp_obj.ehlo()
# Out:
# (250,
#  b'smtp.gmail.com at your service, [172.83.7.202]\nSIZE 35882577\n8BITMIME\nSTARTTLS\nENHANCEDSTATUSCODES\nPIPELINING\nCHUNKING\nSMTPUTF8')

# %%
smtp_obj.starttls()
# Out:
# (220, b'2.0.0 Ready to start TLS')

# %%
password = input('What is your password: ')
# Out:
# What is your password: jhgdu

# %%
import getpass

# %%
password = getpass.getpass('Password please: ')
# Out:
# Password please: ········

# %% [markdown]
# imaplib and email lib

# %%
import imaplib

# %%
M = imaplib.IMAP4_SSL('imap.gmail.com')

# %%
import getpass

# %%
email = getpass.getpass("Email: ")
password = getpass.getpass("Password is: ")

# %%
#M.list()

#M.select('inbox')
